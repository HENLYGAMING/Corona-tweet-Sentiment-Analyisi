# %% [markdown]
# # **Business Problem**

# %% [markdown]
# About Dataset
#
# Perform Text Classification on the data. The tweets have been pulled from Twitter and manual tagging has been done then.
# The names and usernames have been given codes to avoid any privacy concerns.
#
# Columns:
# 1) Location
#
# 2) Tweet At
#
# 3) Original Tweet
#
# 4) Label

# %% [markdown]
# # **Loading the Data**

# %%
import pandas as pd
import numpy as np
import nltk
import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('Corona_NLP_train.csv', encoding='ISO-8859-1')
df_test = pd.read_csv('Corona_NLP_test.csv')

# %%
df_train
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# 0      @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...             Neutral
# 1      advice Talk to your neighbours family to excha...            Positive
# 2      Coronavirus Australia: Woolworths to give elde...            Positive
# 3      My food stock is not the only one which is emp...            Positive
# 4      Me, ready to go at supermarket during the #COV...  Extremely Negative
# ...                                                  ...                 ...
# 41152  Airline pilots offering to stock supermarket s...             Neutral
# 41153  Response to complaint not provided citing COVI...  Extremely Negative
# 41154  You know itÂs getting tough when @KameronWild...            Positive
# 41155  Is it wrong that the smell of hand sanitizer i...             Neutral
# 41156  @TartiiCat Well new/used Rift S are going for ...            Negative
#
# [41157 rows x 6 columns]

# %%
df_test
# Out:
#       UserName  ScreenName             Location     TweetAt  \
# 0            1       44953                  NYC  02-03-2020
# 1            2       44954          Seattle, WA  02-03-2020
# 2            3       44955                  NaN  02-03-2020
# 3            4       44956          Chicagoland  02-03-2020
# 4            5       44957  Melbourne, Victoria  03-03-2020
# ...        ...         ...                  ...         ...
# 3793      3794       48746            Israel ??  16-03-2020
# 3794      3795       48747       Farmington, NM  16-03-2020
# 3795      3796       48748        Haverford, PA  16-03-2020
# 3796      3797       48749                  NaN  16-03-2020
# 3797      3798       48750  Arlington, Virginia  16-03-2020
#
#                                           OriginalTweet           Sentiment
# 0     TRENDING: New Yorkers encounter empty supermar...  Extremely Negative
# 1     When I couldn't find hand sanitizer at Fred Me...            Positive
# 2     Find out how you can protect yourself and love...  Extremely Positive
# 3     #Panic buying hits #NewYork City as anxious sh...            Negative
# 4     #toiletpaper #dunnypaper #coronavirus #coronav...             Neutral
# ...                                                 ...                 ...
# 3793  Meanwhile In A Supermarket in Israel -- People...            Positive
# 3794  Did you panic buy a lot of non-perishable item...            Negative
# 3795  Asst Prof of Economics @cconces was on @NBCPhi...             Neutral
# 3796  Gov need to do somethings instead of biar je r...  Extremely Negative
# 3797  I and @ForestandPaper members are committed to...  Extremely Positive
#
# [3798 rows x 6 columns]

# %% [markdown]
# # **Data Exploration**

# %%
df_train.shape
# Out:
# (41157, 6)

# %%
df_test.shape
# Out:
# (3798, 6)

# %%
df_train.dtypes
# Out:
# UserName          int64
# ScreenName        int64
# Location         object
# TweetAt          object
# OriginalTweet    object
# Sentiment        object
# dtype: object

# %%
df_test.dtypes
# Out:
# UserName          int64
# ScreenName        int64
# Location         object
# TweetAt          object
# OriginalTweet    object
# Sentiment        object
# dtype: object

# %%
for col in df_train.columns.tolist():
  print(col, ': ', df_train[col].nunique())
  print(df_train[col].unique())
  print()
# Out:
# UserName :  41157
# [ 3799  3800  3801 ... 44953 44954 44955]
#
# ScreenName :  41157
# [48751 48752 48753 ... 89905 89906 89907]
#
# Location :  12220
# ['London' 'UK' 'Vagabonds' ... 'Juba south sudan' 'OHIO'
#  'i love you so much || he/him']
#
# TweetAt :  30
# ['16-03-2020' '17-03-2020' '18-03-2020' '19-03-2020' '20-03-2020'
#  '21-03-2020' '22-03-2020' '23-03-2020' '24-03-2020' '25-03-2020'
#  '26-03-2020' '27-03-2020' '28-03-2020' '29-03-2020' '30-03-2020'
#  '31-03-2020' '01-04-2020' '02-04-2020' '03-04-2020' '04-04-2020'
#  '05-04-2020' '06-04-2020' '07-04-2020' '08-04-2020' '09-04-2020'
#  '10-04-2020' '11-04-2020' '12-04-2020' '13-04-2020' '14-04-2020']
#
# OriginalTweet :  41157
# ['@MeNyrbie @Phil_Gahan @Chrisitv https://t.co/iFz9FAn2Pa and https://t.co/xX6ghGFzCC and https://t.co/I2NlzdxNo8'
#  'advice Talk to your neighbours family to exchange phone numbers create contact list with phone numbers of neighbours schools employer chemist GP set up online shopping accounts if poss adequate supplies of regular meds but not over order'
#  'Coronavirus Australia: Woolworths to give elderly, disabled dedicated shopping hours amid COVID-19 outbreak https://t.co/bInCA9Vp8P'
#  ...
#  'You know itÂ\x92s getting tough when @KameronWilds  is rationing toilet paper #coronavirus #toiletpaper @kroger martinsville, help us out!!'
#  'Is it wrong that the smell of hand sanitizer is starting to turn me on?\r\r\n\r\r\n#coronavirus #COVID19 #coronavirus'
#  "@TartiiCat Well new/used Rift S are going for $700.00 on Amazon rn although the normal market price is usually $400.00 . Prices are really crazy right now for vr headsets since HL Alex was announced and it's only been worse with COVID-19. Up to you whethe"]
#
# Sentiment :  5
# ['Neutral' 'Positive' 'Extremely Negative' 'Negative' 'Extremely Positive']

# %%
for col in df_train.columns.tolist():
  print(col, ': ', df_train[col].nunique())
  print(df_train[col].unique())
  print()
# Out:
# UserName :  41157
# [ 3799  3800  3801 ... 44953 44954 44955]
#
# ScreenName :  41157
# [48751 48752 48753 ... 89905 89906 89907]
#
# Location :  12220
# ['London' 'UK' 'Vagabonds' ... 'Juba south sudan' 'OHIO'
#  'i love you so much || he/him']
#
# TweetAt :  30
# ['16-03-2020' '17-03-2020' '18-03-2020' '19-03-2020' '20-03-2020'
#  '21-03-2020' '22-03-2020' '23-03-2020' '24-03-2020' '25-03-2020'
#  '26-03-2020' '27-03-2020' '28-03-2020' '29-03-2020' '30-03-2020'
#  '31-03-2020' '01-04-2020' '02-04-2020' '03-04-2020' '04-04-2020'
#  '05-04-2020' '06-04-2020' '07-04-2020' '08-04-2020' '09-04-2020'
#  '10-04-2020' '11-04-2020' '12-04-2020' '13-04-2020' '14-04-2020']
#
# OriginalTweet :  41157
# ['@MeNyrbie @Phil_Gahan @Chrisitv https://t.co/iFz9FAn2Pa and https://t.co/xX6ghGFzCC and https://t.co/I2NlzdxNo8'
#  'advice Talk to your neighbours family to exchange phone numbers create contact list with phone numbers of neighbours schools employer chemist GP set up online shopping accounts if poss adequate supplies of regular meds but not over order'
#  'Coronavirus Australia: Woolworths to give elderly, disabled dedicated shopping hours amid COVID-19 outbreak https://t.co/bInCA9Vp8P'
#  ...
#  'You know itÂ\x92s getting tough when @KameronWilds  is rationing toilet paper #coronavirus #toiletpaper @kroger martinsville, help us out!!'
#  'Is it wrong that the smell of hand sanitizer is starting to turn me on?\r\r\n\r\r\n#coronavirus #COVID19 #coronavirus'
#  "@TartiiCat Well new/used Rift S are going for $700.00 on Amazon rn although the normal market price is usually $400.00 . Prices are really crazy right now for vr headsets since HL Alex was announced and it's only been worse with COVID-19. Up to you whethe"]
#
# Sentiment :  5
# ['Neutral' 'Positive' 'Extremely Negative' 'Negative' 'Extremely Positive']

# %%
df_train.isnull().sum()
# Out:
# UserName            0
# ScreenName          0
# Location         8590
# TweetAt             0
# OriginalTweet       0
# Sentiment           0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# UserName           0
# ScreenName         0
# Location         834
# TweetAt            0
# OriginalTweet      0
# Sentiment          0
# dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_test.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_train = df_train.drop(columns = {'UserName', 'ScreenName', 'Location', 'TweetAt'})
df_test = df_test.drop(columns = {'UserName', 'ScreenName', 'Location', 'TweetAt'})

# %%
df_train = df_train.sample(20000, random_state = 42)

# %%
df_train['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive              5587
# Negative              4850
# Neutral               3716
# Extremely Positive    3201
# Extremely Negative    2646
# Name: count, dtype: int64

# %%
X = df_train.drop(columns = {'Sentiment'})
y = df_train['Sentiment']

# %%
y.unique()
# Out:
# array(['Neutral', 'Extremely Negative', 'Positive', 'Negative',
#        'Extremely Positive'], dtype=object)

# %%
from imblearn.under_sampling import RandomUnderSampler

rs = RandomUnderSampler(random_state = 0)
X, y = rs.fit_resample(X, y)

# %%
df_train = pd.concat([X, y], axis = 1)

# %%
df_train
# Out:
#                                            OriginalTweet           Sentiment
# 35564  Rice &amp; wheat prices surge amid fears Covid...  Extremely Negative
# 8568   As a carer for elderly parents, will you selfi...  Extremely Negative
# 28089  #Coronavirus' impact on the global food supply...  Extremely Negative
# 28198  @9NewsSyd @tiffgenders @woolworths @Coles @ald...  Extremely Negative
# 13969  Question... anybody ever heard of death cases ...  Extremely Negative
# ...                                                  ...                 ...
# 39882  WeÂre keeping a close eye on agriculture pric...            Positive
# 1090   Please, if you can afford to, get a basket of ...            Positive
# 8842                              Thank you Brad Paisley            Positive
# 2267   We encourage all those impacted by supermarket...            Positive
# 24202  Yup Modi Govt is so beautiful that it increase...            Positive
#
# [13230 rows x 2 columns]

# %% [markdown]
# # **Data (Text) Preprocessing**

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stop_words = stopwords.words('english')

corpus_train = []
for tweet in df_train['OriginalTweet'].tolist():
  l = tweet.lower()
  l = re.sub(r'http\S+', '', tweet)  # Remove URLs
  l = re.sub(r'@\w+', '', tweet)  # Remove mentions
  l = re.sub(r'#\w+', '', tweet)  # Remove hashtags
  l = re.sub('[^a-zA-Z]', ' ', tweet)
  l = l.split()
  l1 = [stemmer.stem(i) for i in l if i not in stop_words]
  l = ' '.join(l1)
  corpus_train.append(l)

print(corpus_train)
# Out:
# ['rice amp wheat price surg amid fear covid lockdown may threaten global food secur increas panic buy food due coronaviru lockdown led price spike world two stapl grain rice amp wheat import rush stockpil good http co qov jap', 'as carer elderli parent selfish stock pile wanker think peopl i tri self isol fear contract viru pass parent howev i ventur tri buy food coronaviru stockpil', 'coronaviru impact global food suppli chain could sky rocket anxieti driven panic say expert http co id zo fn', 'newssyd tiffgend woolworth cole aldi nswhealth vicgovdhh state close contract min danger coronaviru yet one supermarket risk unless huge crowd insid illog overreact senior staff interview fr', 'question anybodi ever heard death case due lack loo paper pl stop panic shop covid covid coronaviru standtogeth oneworld compass empathi solidar stoppanicbuy http co noyz qosc', 'odd could go supermarket buy usual food suppli may may satur coronaviru go extend period exercis outsid home fear catch transmit coronaviru', 'the coronaviru oil price crisi could transform oil industri arctic alaska http co uwbhpnsflw yjrosen http co mowf ozp', 'in difficult time pleas care protect account person inform here tip avoid coronaviru scam http co dddr gelk', 'panic buy no we not run out of food or toilet paper coronaviru myth bust the truth empti shelv toilet paper shortag panicbuy http co urju qc sv', 'sensand the militari everyth need store away the oilygarchi wait desper sell back us outrag price covid', 'i got head supermarket soon get suppli famili if someon want appli social distanc get person space covid worri catch worri catch hand http co rnuyprizci', 'live small town kill right no groceri store deliv store constantli ransack wait time store pickup day week i i stop hoard shit need coronaviru covid', 'covid went supermarket look like explod bread gone bread bad anyway nice know peopl panic buy bad stuff last heard case death counti ridicul', 'we argu yesterday covid crisi financi crisi rather consum small busi crisi requir unusu polici prescript http co rbbmlm', 'caremong maskfear coronaviru covid unlik indian indulg panic food buy canadian throng marijuana store bring stress level', 'ccpviru coronaviru china panic china over alleg food crisi social unrest grow over regim viru respons ccp viru crossroad joshua philipp http co lyjwgcr xa', 'stapl y r non essenti retail worker staplesstor forc work custom shop onlin pickup purchas store without put employe risk covid coronaviru covid flattenthecurv realdonaldtrump gov', 'friedrickjan lbpr mitchellvii as someon depress talk us speak our mental health suffer even lose peopl pandem i rather isol learn manag symptom p', 'bda dietitian urg restraint buy food covid coronaviru pandem seen mani peopl panic buy suppli empti shelv like biggest impact poorest amp vulner member societi http co tkzqj prr', 'so i see post utter fuckwit panic buy complain price go lawsofeconom supplyanddemand covid', 'after find covid case could asymptomat i stress i want go home risk peopl i live everyday work supermarket how arrang altern accommod cohabit key worker mayb empti hotel', 'squeo work meat depart kroger supermarket michigan he know sever groceri worker test posit covid one area die he worri behavior shopper put peopl unnecessari danger', 'there peopl die work walmart polici cpd supervis attorney worker justic racheldeutsch walmart emerg sick leav fatal flaw http co qw lu u c http co wav p dk', 'airtelnigeria we help fight covid data manag split data price packag reduc pain self isol', 'if i see teenag cough purpos food groceri store i slap hell outta parent need get grip coronaviruspandem covid stayathomechalleng', 'the administr propos buy american drug mandat would increas shortag price ultim harm patient now midst coronaviru time implement chang hhsgov whitehous http co kn aeiyjl forb', 'i disappoint mass sinc riot i one guy stockwel suddenli acquir new trainer', 'northumberland polic warn peopl vilig covid scam re ...

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stop_words = stopwords.words('english')

corpus_test = []
for tweet in df_test['OriginalTweet'].tolist():
  l = tweet.lower()
  l = re.sub(r'http\S+', '', tweet)  # Remove URLs
  l = re.sub(r'@\w+', '', tweet)  # Remove mentions
  l = re.sub(r'#\w+', '', tweet)  # Remove hashtags
  l = re.sub('[^a-zA-Z]', ' ', tweet)
  l = l.split()
  l1 = [stemmer.stem(i) for i in l if i not in stop_words]
  l = ' '.join(l1)
  corpus_test.append(l)

print(corpus_test)
# Out:
# ['trend new yorker encount empti supermarket shelv pictur wegman brooklyn sold onlin grocer foodkick maxdeliveri coronaviru fear shopper stock http co gr pcrlwh http co ivmkmsqdt', 'when i find hand sanit fred meyer i turn amazon but pack purel check coronaviru concern drive price http co ygbipbflmi', 'find protect love one coronaviru', 'panic buy hit newyork citi anxiou shopper stock food amp medic suppli healthcar worker becom bigappl st confirm coronaviru patient or bloomberg stage event http co iasiregpc qanon qanon qanon elect cdc http co iszoewxu', 'toiletpap dunnypap coronaviru coronavirusaustralia coronavirusupd covid new corvid newsmelb dunnypaperg costco one week everyon buy babi milk powder next everyon buy toilet paper http co sczryvvsih', 'do rememb last time paid gallon regular ga lo angel price pump go a look coronaviru impact price pm abc http co pyzq ymuv', 'vote age coronaviru hand sanit supertuesday http co z bel o dk', 'drtedro we stop covid without protect healthwork price surgic mask increas six fold n respir trebl amp gown cost twice much drtedro coronaviru', 'hi twitter i pharmacist i sell hand sanit live or i exist like mask sold fuck everywher should you be worri no use soap should you visit twenti pharmaci look for the last bottl no pharmaci full sick peopl', 'anyon supermarket last day went normal shop last night amp sight greet barmi btw special tin tomato covid dublin http co rgsm xuxr', 'best qualiti couch unbeliev low price avail order we boksburg gp for info whatsapp supertuesdsi powertalk covid sayentrepreneur djsbu http co hhdjhyq dc', 'bewar counterfeit tri sell fake mask cheap price let defeat coronaviru threat covid collect besaf beacascad coronavirusreachesdelhi coronavirusindia http co ikkmimj f http co rb rtt nkc', 'panic food buy germani due coronaviru begun but organ left behind hamsterkauf panic buy call hamster purchas hamsterk ufe german taken way hamster stuff cheek food http co ayqtllgw', 'covid went groceri store turn clean suppli bought fear coronaviru my daughter substitut teacher show class make hand sanit now i need buy alcohol wish luck store', 'while busi watch elect return brace covid outbreak trump nomin chemic industri lobbyist head consum product safeti commiss http co m shhi tn', 'airsewa flyspicejet provid webchecin custom free seat passeng forc choos paid seat free seat made avail airport counter thi stop discriminatori travel right hardeepspuri moca goi', 'what precautionari measur taken respect restaur hotel comment covid coronaviru covid hotel chain enforc precautionari measur issu safeti hygien advisori http co zo vqspzi', 'when stockpil food amp suppli buy extra local food bank mani famili luxuri spend beyond weekli budget dailybreadto coronaviru', 'that week a bit optimist probabl take anoth month suppli chain may recov demand chain non exist us europ next month two spx qqq es nq http co yxcofl bni', 'studi show coronaviru like covid live nine day hard surfac like metal plastic glass our deputi commission consum affair mari barze flore show keep clean ga pump watch share http co aiqatwt zz', 'coronaviru covid peopl start becom frighten panicshop mani shelv meanwhil turn empti good sold facemask amp disinfect liquid sold sold exorbit price blockchain cryptonew http co akr lmlekf', 'for think credit debit good bitcoin come combat coronaviru keep mind contactless transact how mani peopl groceri store ga station touch keypad everi day http co wvq bb ol', 'control stock gold lost gold come back nice love wallbridg balmor warn listen coronaviru sprott money ltd recent put money ocg genm mmg mani http co aurz e sj', 'seller cash panic sell facemask sanit super inflat price in realiti neither sanit facemask must save coronaviru pleas watch video http co sgofnau j', 'canada oilpatch brace impact plung crude price opec alli fail reach deal aim cut product economi slow novel coronaviru the fool jkenney base budget hire oil price http co fdcpqpvpuo', 'alright i hope melan ...

# %% [markdown]
# **Vectorization**

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X_train = pd.DataFrame(vectorizer.fit_transform(corpus_train).toarray(), columns = vectorizer.get_feature_names_out())
X_test = pd.DataFrame(vectorizer.transform(corpus_test).toarray(), columns = vectorizer.get_feature_names_out())

# %%
y_train = df_train['Sentiment']
y_test = df_test['Sentiment']

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train, y_train)

#Prediction
ypred_train = model.predict(X_train)
ypred_test = model.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score

accuracy_train = accuracy_score(y_train, ypred_train)
accuracy_test = accuracy_score(y_test, ypred_test)

print('Accuracy(Train): ', accuracy_train)
print('Accuracy(Test): ', accuracy_test)
# Out:
# Accuracy(Train):  0.8254724111866969
# Accuracy(Test):  0.4178515007898894

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)

#Prediction
ypred_train = model.predict(X_train)
ypred_test = model.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score

accuracy_train = accuracy_score(y_train, ypred_train)
accuracy_test = accuracy_score(y_test, ypred_test)

print('Accuracy(Train): ', accuracy_train)
print('Accuracy(Test): ', accuracy_test)
# Out:
# Accuracy(Train):  0.9832199546485261
# Accuracy(Test):  0.5078988941548184

# %%
from sklearn.svm import LinearSVC

model = LinearSVC()
model.fit(X_train, y_train)

#Prediction
ypred_train = model.predict(X_train)
ypred_test = model.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score

accuracy_train = accuracy_score(y_train, ypred_train)
accuracy_test = accuracy_score(y_test, ypred_test)

print('Accuracy(Train): ', accuracy_train)
print('Accuracy(Test): ', accuracy_test)
# Out:
# Accuracy(Train):  0.9985638699924414
# Accuracy(Test):  0.46340179041600843
